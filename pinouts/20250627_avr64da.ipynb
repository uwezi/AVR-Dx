# %%
import camelot

tables = camelot.read_pdf(r'D:\uwezi\elo\datasheet\Atmel\AVR64DB28-32-48-64-DataSheet-DS40002300.pdf'
                          , pages='18,19')

# %%
tables
# Out:
# <TableList n=2>

# %%
print (tables[0].parsing_report)
# Out:
# {'accuracy': 100.0, 'whitespace': 58.24, 'order': 1, 'page': 18}

# %%
tables[0].df
# Out:
#     0   1   2   3       4                5      6   \
# 0   62  44  30  22     PA0  XTALHF1\nEXTCLK
# 1   63  45  31  23     PA1          XTALHF2
# 2   64  46  32  24     PA2          TWI Fm+
# 3    1  47   1  25     PA3          TWI Fm+
# 4    2  48   2  26     PA4
# 5    3   1   3  27     PA5
# 6    4   2   4  28     PA6
# 7    5   3   5   1     PA7           CLKOUT
# 8    6                 VDD
# 9    7                 GND
# 10   8   4             PB0
# 11   9   5             PB1
# 12  10   6             PB2              TWI
# 13  11   7             PB3              TWI
# 14  12   8             PB4
# 15  13   9             PB5
# 16  14                 PB6
# 17  15                 PB7
# 18  16  10   6   2     PC0
# 19  17  11   7   3     PC1
# 20  18  12   8   4     PC2          TWI Fm+
# 21  19  13   9   5     PC3          TWI Fm+
# 22  20  14  10   6  VDDIO2
# 23  21  15             GND
# 24  22  16             PC4
# 25  23  17             PC5
# 26  24  18             PC6
# ...

# %%
tables.export(r'D:\uwezi\elo\datasheet\Atmel\foo.csv', f='csv')
